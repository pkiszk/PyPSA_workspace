# %%
import pandas as pd
import numpy as np

mydf = pd.read_csv("PSE_his-wlk-cal.csv")


#display(mydf.head)

#mydf['dtime']
mydf.head() #first 5 cols
mydf.tail()
mydf.dtypes

# %%
mydf.describe()

# %%
mydf['jgw1']

# %%
mydf.loc[5:8]

# %%
mydf.columns

# %%
#subsetting columns 

df2 = mydf[['dtime_utc', 'period_utc', 'dtime', 'period', 'business_date',
       'publication_ts', 'publication_ts_utc']]

# %%
df2.head()

# %%
df2.describe()

# %%
df2.shape

# %%
mydf.shape

# %%
# subsettting rows

mydf.loc[mydf['jgw1'] > 33]

# %%
mydf.query('jgw1 > 12000')
# Out:
#                 dtime_utc     period_utc                dtime         period  \
# 22    2025-02-01 05:30:00  05:15 - 05:30  2025-02-01 06:30:00  06:15 - 06:30
# 23    2025-02-01 05:45:00  05:30 - 05:45  2025-02-01 06:45:00  06:30 - 06:45
# 24    2025-02-01 06:00:00  05:45 - 06:00  2025-02-01 07:00:00  06:45 - 07:00
# 25    2025-02-01 06:15:00  06:00 - 06:15  2025-02-01 07:15:00  07:00 - 07:15
# 26    2025-02-01 06:30:00  06:15 - 06:30  2025-02-01 07:30:00  07:15 - 07:30
# ...                   ...            ...                  ...            ...
# 2675  2025-02-28 20:45:00  20:30 - 20:45  2025-02-28 21:45:00  21:30 - 21:45
# 2677  2025-02-28 21:15:00  21:00 - 21:15  2025-02-28 22:15:00  22:00 - 22:15
# 2678  2025-02-28 21:30:00  21:15 - 21:30  2025-02-28 22:30:00  22:15 - 22:30
# 2679  2025-02-28 21:45:00  21:30 - 21:45  2025-02-28 22:45:00  22:30 - 22:45
# 2681  2025-02-28 22:15:00  22:00 - 22:15  2025-02-28 23:15:00  23:00 - 23:15
#
# ...

# %%
#sumuje wszystkie wiersze gdzie jgm1 == 0

#mydf.query('jgm1 ==0').sum()

#zlicza ilosc wierszy spelniajacych:
(mydf['jgm1']>0).sum()
# Out:
# np.int64(1088)

# %%
mydf.dtypes
# Out:
# dtime_utc              object
# period_utc             object
# dtime                  object
# period                 object
# business_date          object
# publication_ts         object
# publication_ts_utc     object
# jg                    float64
# pv                    float64
# wi                    float64
# demand                float64
# jga                   float64
# jgm                   float64
# jgo                   float64
# jgm1                  float64
# jgm2                  float64
# jgw1                  float64
# jgw2                  float64
# jgz1                  float64
# jgz2                  float64
# jgz3                  float64
# jnwrb                 float64
# swm_p                 float64
# swm_np                float64
# dtype: object

# %%
mydf.dtypes
# Out:
# dtime_utc              object
# period_utc             object
# dtime                  object
# period                 object
# business_date          object
# publication_ts         object
# publication_ts_utc     object
# jg                    float64
# pv                    float64
# wi                    float64
# demand                float64
# jga                   float64
# jgm                   float64
# jgo                   float64
# jgm1                  float64
# jgm2                  float64
# jgw1                  float64
# jgw2                  float64
# jgz1                  float64
# jgz2                  float64
# jgz3                  float64
# jnwrb                 float64
# swm_p                 float64
# swm_np                float64
# dtype: object

# %%
mydf['dtime_utc'] = pd.to_datetime(mydf['dtime_utc'])

# %%
mydf.dtypes
# Out:
# dtime_utc             datetime64[ns]
# period_utc                    object
# dtime                         object
# period                        object
# business_date                 object
# publication_ts                object
# publication_ts_utc            object
# jg                           float64
# pv                           float64
# wi                           float64
# demand                       float64
# jga                          float64
# jgm                          float64
# jgo                          float64
# jgm1                         float64
# jgm2                         float64
# jgw1                         float64
# jgw2                         float64
# jgz1                         float64
# jgz2                         float64
# jgz3                         float64
# jnwrb                        float64
# swm_p                        float64
# swm_np                       float64
# dtype: object

# %%
mydf.head()
# Out:
#             dtime_utc     period_utc                dtime         period  \
# 0 2025-02-01 00:00:00  23:45 - 24:00  2025-02-01 01:00:00  00:45 - 01:00
# 1 2025-02-01 00:15:00  00:00 - 00:15  2025-02-01 01:15:00  01:00 - 01:15
# 2 2025-02-01 00:30:00  00:15 - 00:30  2025-02-01 01:30:00  01:15 - 01:30
# 3 2025-02-01 00:45:00  00:30 - 00:45  2025-02-01 01:45:00  01:30 - 01:45
# 4 2025-02-01 01:00:00  00:45 - 01:00  2025-02-01 02:00:00  01:45 - 02:00
#
#   business_date           publication_ts       publication_ts_utc         jg  \
# 0    2025-02-01  2026-01-18 02:27:15.804  2026-01-18 01:27:15.804  11431.255
# 1    2025-02-01  2026-01-18 02:27:15.804  2026-01-18 01:27:15.804  11437.325
# 2    2025-02-01  2026-01-18 02:27:15.804  2026-01-18 01:27:15.804  11348.854
# 3    2025-02-01  2026-01-18 02:27:15.804  2026-01-18 01:27:15.804  11361.732
# 4    2025-02-01  2026-01-18 02:27:15.804  2026-01-18 01:27:15.804  11300.089
#
# ...

# %%
mydf.head()
# Out:
#             dtime_utc     period_utc                dtime         period  \
# 0 2025-02-01 00:00:00  23:45 - 24:00  2025-02-01 01:00:00  00:45 - 01:00
# 1 2025-02-01 00:15:00  00:00 - 00:15  2025-02-01 01:15:00  01:00 - 01:15
# 2 2025-02-01 00:30:00  00:15 - 00:30  2025-02-01 01:30:00  01:15 - 01:30
# 3 2025-02-01 00:45:00  00:30 - 00:45  2025-02-01 01:45:00  01:30 - 01:45
# 4 2025-02-01 01:00:00  00:45 - 01:00  2025-02-01 02:00:00  01:45 - 02:00
#
#   business_date           publication_ts       publication_ts_utc         jg  \
# 0    2025-02-01  2026-01-18 02:27:15.804  2026-01-18 01:27:15.804  11431.255
# 1    2025-02-01  2026-01-18 02:27:15.804  2026-01-18 01:27:15.804  11437.325
# 2    2025-02-01  2026-01-18 02:27:15.804  2026-01-18 01:27:15.804  11348.854
# 3    2025-02-01  2026-01-18 02:27:15.804  2026-01-18 01:27:15.804  11361.732
# 4    2025-02-01  2026-01-18 02:27:15.804  2026-01-18 01:27:15.804  11300.089
#
# ...

# %%
mydf['ratio']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ratio'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ...
